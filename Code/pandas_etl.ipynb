# %%
# Import 
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Load CSVs

# %%
# Extract listing CSV into dataframe
listings_file = "../Resources/listings.csv"
raw_listings_df = pd.read_csv(listings_file)
raw_listings_df.head()
# Out:
#      id                                               name  host_id  \
# 0   109  Amazing bright elegant condo park front *UPGRA...      521
# 1   344                  Family perfect;Pool;Near Studios!      767
# 2  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     3008
# 3  2732                              Zen Life at the Beach     3041
# 4  2864  *Upscale Professional Home with Beautiful Studio*     3207
#
#         host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0           Paolo         Other Cities   Culver City  33.98209 -118.38494
# 1         Melissa         Other Cities       Burbank  34.16562 -118.33458
# 2           Chas.  City of Los Angeles     Hollywood  34.09768 -118.34602
# 3  Yoga Priestess         Other Cities  Santa Monica  34.00475 -118.48127
# 4       Bernadine         Other Cities    Bellflower  33.87619 -118.11397
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    122              30                  2  2016-05-15
# 1  Entire home/apt    168               2                  8  2019-10-19
# 2     Private room     79              30                 24  2020-03-17
# 3     Private room    155               1                 21  2019-12-27
# 4  Entire home/apt     80               2                  0         NaN
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.02                               1                14
# 1               0.17                               1                73
# 2               0.34                               2               281
# 3               0.19                               2               365
# 4                NaN                               1                 0

# %%
# Extract review CSV into dataframe
reviews_file = "../Resources/reviews.csv"
raw_reviews_df = pd.read_csv(reviews_file)
raw_reviews_df.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0         109     449036  2011-08-15       927861         Edwin
# 1         109   74506539  2016-05-15     22509885          Jenn
# 2         344   79805581  2016-06-14      2089550  Drew & Katie
# 3         344  120725697  2016-12-11     32602867   Christopher
# 4         344  123800867  2016-12-30     35822259           May
#
#                                             comments
# 0  The host canceled my reservation the day befor...
# 1  Me and two friends stayed for four and a half ...
# 2  We really enjoyed our stay here in Burbank! Th...
# 3  I had a ton of fun learning to play Go with Fu...
# 4  The host canceled this reservation the day bef...

# %%
# We are only interested in the listings around centre of LA
# Select significant columns
central_listing_df=raw_listings_df.loc[raw_listings_df["neighbourhood_group"]=="City of Los Angeles",["id",
                                                                                                      "name",
                                                                                                      "host_name",
                                                                                                     "neighbourhood",
                                                                                                      "room_type",
                                                                                                     "price",
                                                                                                     "number_of_reviews",
                                                                                                     "last_review"]]


central_listing_df.head(5)
# Out:
#      id                                               name host_name  \
# 2  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 5  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
# 6  5728    Tiny Home in Artistic Oasis near Venice and LAX     Sanni
# 7  5729     Zen Room with Floating Bed near Venice and LAX     Sanni
# 8  5843  Artist Oasis near Venice Beach w/ Beautiful Ga...     Sanni
#
#           neighbourhood        room_type  price  number_of_reviews last_review
# 2             Hollywood     Private room     79                 24  2020-03-17
# 5  Hollywood Hills West  Entire home/apt    145                 23  2018-10-31
# 6               Del Rey     Private room     75                309  2020-03-13
# 7               Del Rey     Private room    105                228  2020-03-09
# 8               Del Rey  Entire home/apt    303                126  2020-03-16

# %%
# Change index column name in review dataframe so both dataframes can join 
raw_reviews_df_id = raw_reviews_df.rename(columns={"listing_id": "id",
                                                   "id":"host id"})
raw_reviews_df_id.head(5)
# Out:
#     id    host id        date  reviewer_id reviewer_name  \
# 0  109     449036  2011-08-15       927861         Edwin
# 1  109   74506539  2016-05-15     22509885          Jenn
# 2  344   79805581  2016-06-14      2089550  Drew & Katie
# 3  344  120725697  2016-12-11     32602867   Christopher
# 4  344  123800867  2016-12-30     35822259           May
#
#                                             comments
# 0  The host canceled my reservation the day befor...
# 1  Me and two friends stayed for four and a half ...
# 2  We really enjoyed our stay here in Burbank! Th...
# 3  I had a ton of fun learning to play Go with Fu...
# 4  The host canceled this reservation the day bef...

# %%
central_listing_df.shape
# Out:
# (22058, 8)

# %%
raw_reviews_df_id.shape
# Out:
# (1339115, 6)

# %%
# Merge both dataframe on column id 
complete_df=pd.merge(central_listing_df, raw_reviews_df_id, how='inner', on="id")
complete_df.head(30)
# Out:
#       id                                               name host_name  \
# 0   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 1   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 2   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 3   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 4   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 5   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 6   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 7   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 8   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 9   2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 10  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 11  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 12  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 13  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 14  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 15  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 16  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 17  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 18  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 19  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 20  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 21  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 22  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 23  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 24  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
# 25  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
# 26  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
# 27  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
# 28  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
# 29  3021    Hollywood Hills Zen Modern style Apt/Guesthouse   Nataraj
#
#            neighbourhood        room_type  price  number_of_reviews  \
# 0              Hollywood     Private room     79                 24
# 1              Hollywood     Private room     79                 24
# 2              Hollywood     Private room     79                 24
# 3              Hollywood     Private room     79                 24
# 4              Hollywood     Private room     79                 24
# 5              Hollywood     Private room     79                 24
# 6              Hollywood     Private room     79                 24
# 7              Hollywood     Private room     79                 24
# 8              Hollywood     Private room     79                 24
# 9              Hollywood     Private room     79                 24
# 10             Hollywood     Private room     79                 24
# 11             Hollywood     Private room     79                 24
# 12             Hollywood     Private room     79                 24
# 13             Hollywood     Private room     79                 24
# 14             Hollywood     Private room     79                 24
# 15             Hollywood     Private room     79                 24
# 16             Hollywood     Private room     79                 24
# 17             Hollywood     Private room     79                 24
# 18             Hollywood     Private room     79                 24
# 19             Hollywood     Private room     79                 24
# 20             Hollywood     Private room     79                 24
# 21             Hollywood     Private room     79                 24
# 22             Hollywood     Private room     79                 24
# 23             Hollywood     Private room     79                 24
# 24  Hollywood Hills West  Entire home/apt    145                 23
# 25  Hollywood Hills West  Entire home/apt    145                 23
# 26  Hollywood Hills West  Entire home/apt    145                 23
# 27  Hollywood Hills West  Entire home/apt    145                 23
# 28  Hollywood Hills West  Entire home/apt    145                 23
# 29  Hollywood Hills West  Entire home/apt    145                 23
#
#    last_review    host id        date  reviewer_id     reviewer_name  \
# 0   2020-03-17   13994902  2014-06-09     10905424           Kuberan
# 1   2020-03-17   14606598  2014-06-23      2247288           Camilla
# 2   2020-03-17   39597339  2015-07-25     27974696            Fallon
# 3   2020-03-17   61157407  2016-02-01     33226412            Haroon
# 4   2020-03-17   66196280  2016-03-20     23408691  Massimo Litterio
# 5   2020-03-17  222420570  2017-12-29    155985882            Manami
# 6   2020-03-17  225209928  2018-01-05      6840784             Diego
# 7   2020-03-17  227042674  2018-01-13    162469426            Hanbin
# 8   2020-03-17  284617908  2018-07-01     93292025         Harjinder
# 9   2020-03-17  291375787  2018-07-15    183639942            Taylor
# 10  2020-03-17  296879491  2018-07-26     37846734              John
# 11  2020-03-17  306500549  2018-08-12     48408491            Andrew
# 12  2020-03-17  319965969  2018-09-07     51146446         Stephanie
# 13  2020-03-17  358265929  2018-12-13    118296038      Aziz Ibrahim
# 14  2020-03-17  417933068  2019-02-28    153706631            Andrea
# 15  2020-03-17  425630420  2019-03-18     13903098              Tami
# 16  2020-03-17  443320279  2019-04-25    228846650          Stefanie
# 17  2020-03-17  448958815  2019-05-05      2126071                Kj
# 18  2020-03-17  452259654  2019-05-12    141434769           Matthew
# 19  2020-03-17  456137752  2019-05-20    249489563            Morgan
# 20  2020-03-17  501551096  2019-08-03    249142508            Steven
# 21  2020-03-17  521262231  2019-08-31     32253750            Adrian
# 22  2020-03-17  576181646  2019-12-12     79475501             Jenny
# 23  2020-03-17  619302203  2020-03-17    117823684            Nathan
# 24  2018-10-31    7010448  2013-09-03      7008708               Kim
# 25  2018-10-31   11271580  2014-03-27     13263115           Richard
# 26  2018-10-31   12432298  2014-05-02      8917495         Alexander
# 27  2018-10-31   50696133  2015-10-13         7338              Alex
# 28  2018-10-31   85297917  2016-07-11     82124588            Krista
# 29  2018-10-31   87864389  2016-07-22     47318391           Michael
#
#                                              comments
# 0   i had a wonderful stay. Everything from start ...
# 1   Charles is just amazing and he made my stay sp...
# 2   Staying with Chas was an absolute pleasure. He...
# 3   Charles is a most wonderful host. I enjoyed my...
# 4   Chas is a really good host. He gives me a lot ...
# 5   ﾎｽﾄはとても親切で英語の発音の仕方など丁寧に教えてくれた｡\n\n部屋はﾘﾋﾞﾝｸﾞを板で...
# 6   Chas house feels like home, it is clean, it ha...
# 7   1. Clean 2. Host is very friendly 3. Reasonabl...
# 8   Wow; Charles was a delight to meet a very warm...
# 9   Chas. has a great space ! Loved how clean ever...
# 10  Chas is a great host, very friendly and welcom...
# 11  Charles place is lovely and in a great locatio...
# 12  Charles's place is great! It is very clean and...
# 13  Charles place will not disappoint for a second...
# 14  Chas is an amazing host and I absolutely recom...
# 15  Chas. is an excellent host, and this is a grea...
# 16  I had an amazing time at Charles place. He mad...
# 17  Chas was very hospitable! I would stay here ag...
# 18  As you might have gleaned from the other revie...
# 19  I had a great time at Charles place, he is a g...
# 20  Great place and great location. Charles is ver...
# 21  Chas place is a gem, conveniently located to s...
# 22         Wonderful hospitality, strongly recommend!
# 23  Location is decent (near some great music stor...
# 24  I've lived in Los Angeles for 23 years. My fav...
# 25  I have stayed here twice. Loved the experience...
# 26  Nataraj was helpful from the very beginning an...
# 27                             Better luck next time
# 28  Great place, the host was really really helpfu...
# 29  Not my favorite place i've airbnb at. Maybe ok...

# %%
complete_df.shape
# Out:
# (811168, 13)

# %%
# Rename the column headers
renamed_complete_df = complete_df.rename(columns={"id": "Listing ID",
                                                "name": "Listing Title",
                                                "host_name": "Host Name",
                                                  "host id":"Host ID",
                                                 "neighbourhood":"Region",
                                                 "room_type":"Room Type",
                                                 "price":"Price per Night",
                                                 "number_of_reviews":"Number of Reviews",
                                                 "last_review":"Last Review Time",
                                                 "date":"Review Date",
                                                  "reviewer_name":"Reviewer Name",
                                                  "reviewer_id":"Reviewer ID",
                                                  "comments":"Comments"
                                                 })


# Clean the data by dropping duplicates and nulls
renamed_complete_df.drop_duplicates("Comments", inplace=True)
renamed_complete_df.dropna()

renamed_complete_df.head(20)
# Out:
#     Listing ID                                      Listing Title Host Name  \
# 0         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 1         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 2         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 3         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 4         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 5         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 6         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 7         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 8         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 9         2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 10        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 11        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 12        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 13        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 14        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 15        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 16        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 17        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 18        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
# 19        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     Chas.
#
#        Region     Room Type  Price per Night  Number of Reviews  \
# 0   Hollywood  Private room               79                 24
# 1   Hollywood  Private room               79                 24
# 2   Hollywood  Private room               79                 24
# 3   Hollywood  Private room               79                 24
# 4   Hollywood  Private room               79                 24
# 5   Hollywood  Private room               79                 24
# 6   Hollywood  Private room               79                 24
# 7   Hollywood  Private room               79                 24
# 8   Hollywood  Private room               79                 24
# 9   Hollywood  Private room               79                 24
# 10  Hollywood  Private room               79                 24
# 11  Hollywood  Private room               79                 24
# 12  Hollywood  Private room               79                 24
# 13  Hollywood  Private room               79                 24
# 14  Hollywood  Private room               79                 24
# 15  Hollywood  Private room               79                 24
# 16  Hollywood  Private room               79                 24
# 17  Hollywood  Private room               79                 24
# 18  Hollywood  Private room               79                 24
# 19  Hollywood  Private room               79                 24
#
#    Last Review Time    Host ID Review Date  Reviewer ID     Reviewer Name  \
# 0        2020-03-17   13994902  2014-06-09     10905424           Kuberan
# 1        2020-03-17   14606598  2014-06-23      2247288           Camilla
# 2        2020-03-17   39597339  2015-07-25     27974696            Fallon
# 3        2020-03-17   61157407  2016-02-01     33226412            Haroon
# 4        2020-03-17   66196280  2016-03-20     23408691  Massimo Litterio
# 5        2020-03-17  222420570  2017-12-29    155985882            Manami
# 6        2020-03-17  225209928  2018-01-05      6840784             Diego
# 7        2020-03-17  227042674  2018-01-13    162469426            Hanbin
# 8        2020-03-17  284617908  2018-07-01     93292025         Harjinder
# 9        2020-03-17  291375787  2018-07-15    183639942            Taylor
# 10       2020-03-17  296879491  2018-07-26     37846734              John
# 11       2020-03-17  306500549  2018-08-12     48408491            Andrew
# 12       2020-03-17  319965969  2018-09-07     51146446         Stephanie
# 13       2020-03-17  358265929  2018-12-13    118296038      Aziz Ibrahim
# 14       2020-03-17  417933068  2019-02-28    153706631            Andrea
# 15       2020-03-17  425630420  2019-03-18     13903098              Tami
# 16       2020-03-17  443320279  2019-04-25    228846650          Stefanie
# 17       2020-03-17  448958815  2019-05-05      2126071                Kj
# 18       2020-03-17  452259654  2019-05-12    141434769           Matthew
# 19       2020-03-17  456137752  2019-05-20    249489563            Morgan
#
#                                              Comments
# 0   i had a wonderful stay. Everything from start ...
# 1   Charles is just amazing and he made my stay sp...
# 2   Staying with Chas was an absolute pleasure. He...
# 3   Charles is a most wonderful host. I enjoyed my...
# 4   Chas is a really good host. He gives me a lot ...
# 5   ﾎｽﾄはとても親切で英語の発音の仕方など丁寧に教えてくれた｡\n\n部屋はﾘﾋﾞﾝｸﾞを板で...
# 6   Chas house feels like home, it is clean, it ha...
# 7   1. Clean 2. Host is very friendly 3. Reasonabl...
# 8   Wow; Charles was a delight to meet a very warm...
# 9   Chas. has a great space ! Loved how clean ever...
# 10  Chas is a great host, very friendly and welcom...
# 11  Charles place is lovely and in a great locatio...
# 12  Charles's place is great! It is very clean and...
# 13  Charles place will not disappoint for a second...
# 14  Chas is an amazing host and I absolutely recom...
# 15  Chas. is an excellent host, and this is a grea...
# 16  I had an amazing time at Charles place. He mad...
# 17  Chas was very hospitable! I would stay here ag...
# 18  As you might have gleaned from the other revie...
# 19  I had a great time at Charles place, he is a g...

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/ETL"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['listing_review']

# %% [markdown]
# ### Load DataFrame into database

# %%
renamed_complete_df.dtypes
# Out:
# Listing ID            int64
# Listing Title        object
# Host Name            object
# Region               object
# Room Type            object
# Price per Night       int64
# Number of Reviews     int64
# Last Review Time     object
# Host ID               int64
# Review Date          object
# Reviewer ID           int64
# Reviewer Name        object
# Comments             object
# dtype: object

# %%
renamed_complete_df["Last Review Time"] = pd.to_datetime(renamed_complete_df["Last Review Time"], format="%Y-%m-%d")

# %%
renamed_complete_df["Review Date"] = pd.to_datetime(renamed_complete_df["Review Date"], format="%Y-%m-%d")

# %%
renamed_complete_df.dtypes
# Out:
# Listing ID                    int64
# Listing Title                object
# Host Name                    object
# Region                       object
# Room Type                    object
# Price per Night               int64
# Number of Reviews             int64
# Last Review Time     datetime64[ns]
# Host ID                       int64
# Review Date          datetime64[ns]
# Reviewer ID                   int64
# Reviewer Name                object
# Comments                     object
# dtype: object

# %%
renamed_complete_df.to_sql(name='listing_review', con=engine, if_exists='replace', index=True)

# %%
check_df = pd.read_sql(sql="SELECT * FROM listing_review", con=engine, parse_dates=["Review Date","Last Review Time"])
check_df.head()
# Out:
#    index  Listing ID                                      Listing Title  \
# 0      0        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 1      1        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 2      2        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3      3        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 4      4        2708  Mirrored Mini-Suite with Fireplace - W. Hollywood
#
#   Host Name     Region     Room Type  Price per Night  Number of Reviews  \
# 0     Chas.  Hollywood  Private room               79                 24
# 1     Chas.  Hollywood  Private room               79                 24
# 2     Chas.  Hollywood  Private room               79                 24
# 3     Chas.  Hollywood  Private room               79                 24
# 4     Chas.  Hollywood  Private room               79                 24
#
#   Last Review Time   Host ID Review Date  Reviewer ID     Reviewer Name  \
# 0       2020-03-17  13994902  2014-06-09     10905424           Kuberan
# 1       2020-03-17  14606598  2014-06-23      2247288           Camilla
# 2       2020-03-17  39597339  2015-07-25     27974696            Fallon
# 3       2020-03-17  61157407  2016-02-01     33226412            Haroon
# 4       2020-03-17  66196280  2016-03-20     23408691  Massimo Litterio
#
#                                             Comments
# 0  i had a wonderful stay. Everything from start ...
# 1  Charles is just amazing and he made my stay sp...
# 2  Staying with Chas was an absolute pleasure. He...
# 3  Charles is a most wonderful host. I enjoyed my...
# 4  Chas is a really good host. He gives me a lot ...

# %%
check_df.dtypes
# Out:
# index                         int64
# Listing ID                    int64
# Listing Title                object
# Host Name                    object
# Region                       object
# Room Type                    object
# Price per Night               int64
# Number of Reviews             int64
# Last Review Time     datetime64[ns]
# Host ID                       int64
# Review Date          datetime64[ns]
# Reviewer ID                   int64
# Reviewer Name                object
# Comments                     object
# dtype: object
